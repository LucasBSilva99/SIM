# %%
import pandas as pd 
# %matplotlib inline


cars_df = pd.read_csv('D:\\Lusofona\\3ºAno\\SIM\\cars.csv', sep=";") 

cars_df
# Out:
#      Unnamed: 0 manufacturer               model  displ  year  cyl  \
# 0             1         audi                  a4    1.8  1999    4
# 1             2         audi                  a4    1.8  1999    4
# 2             3         audi                  a4    2.0  2008    4
# 3             4         audi                  a4    2.0  2008    4
# 4             5         audi                  a4    2.8  1999    6
# 5             6         audi                  a4    2.8  1999    6
# 6             7         audi                  a4    3.1  2008    6
# 7             8         audi          a4 quattro    1.8  1999    4
# 8             9         audi          a4 quattro    1.8  1999    4
# 9            10         audi          a4 quattro    2.0  2008    4
# 10           11         audi          a4 quattro    2.0  2008    4
# 11           12         audi          a4 quattro    2.8  1999    6
# 12           13         audi          a4 quattro    2.8  1999    6
# ...

# %%
type(cars_df.cyl)
# Out:
# pandas.core.series.Series

# %%
cars_df[cars_df['manufacturer']=="volkswagen"]
# Out:
#      Unnamed: 0 manufacturer       model  displ  year  cyl       trans drv  \
# 207         208   volkswagen         gti    2.0  1999    4  manual(m5)   f
# 208         209   volkswagen         gti    2.0  1999    4    auto(l4)   f
# 209         210   volkswagen         gti    2.0  2008    4  manual(m6)   f
# 210         211   volkswagen         gti    2.0  2008    4    auto(s6)   f
# 211         212   volkswagen         gti    2.8  1999    6  manual(m5)   f
# 212         213   volkswagen       jetta    1.9  1999    4  manual(m5)   f
# 213         214   volkswagen       jetta    2.0  1999    4  manual(m5)   f
# 214         215   volkswagen       jetta    2.0  1999    4    auto(l4)   f
# 215         216   volkswagen       jetta    2.0  2008    4    auto(s6)   f
# 216         217   volkswagen       jetta    2.0  2008    4  manual(m6)   f
# 217         218   volkswagen       jetta    2.5  2008    5    auto(s6)   f
# ...

# %%
cars_df[cars_df['year']==1999]
# Out:
#      Unnamed: 0 manufacturer                   model  displ  year  cyl  \
# 0             1         audi                      a4    1.8  1999    4
# 1             2         audi                      a4    1.8  1999    4
# 4             5         audi                      a4    2.8  1999    6
# 5             6         audi                      a4    2.8  1999    6
# 7             8         audi              a4 quattro    1.8  1999    4
# 8             9         audi              a4 quattro    1.8  1999    4
# 11           12         audi              a4 quattro    2.8  1999    6
# 12           13         audi              a4 quattro    2.8  1999    6
# 15           16         audi              a6 quattro    2.8  1999    6
# 21           22    chevrolet      c1500 suburban 2wd    5.7  1999    8
# 23           24    chevrolet                corvette    5.7  1999    8
# 24           25    chevrolet                corvette    5.7  1999    8
# ...

# %%
cars_df.cyl.plot(kind="hist")

# %%
cars_df.groupby(["cyl"]).count()
# Out:
#      Unnamed: 0  manufacturer  model  displ  year  trans  drv  cty  hwy  fl  \
# cyl
# 4            81            81     81     81    81     81   81   81   81  81
# 5             4             4      4      4     4      4    4    4    4   4
# 6            78            78     78     78    78     78   78   78   78  78
# 8            70            70     70     70    70     70   70   70   70  70
#
#      class
# cyl
# 4       81
# 5        4
# 6       78
# 8       70

# %%
cars_df.groupby(["cyl"]).count().model.plot(kind = "bar")

# %%
cars_df.groupby(["hwy"]).count().model.plot(kind = "bar")

# %%
cars_df.groupby(["cyl"]).hwy.mean()
# Out:
# cyl
# 4    28.802469
# 5    28.750000
# 6    22.782051
# 8    17.628571
# Name: hwy, dtype: float64

# %%
cars_df.groupby(["class"]).hwy.mean().map(lambda x: round(x,2))
# Out:
# class
# 2seater       24.80
# compact       28.30
# midsize       27.32
# minivan       22.36
# pickup        16.88
# subcompact    28.14
# suv           18.13
# Name: hwy, dtype: float64

# %%
cars_df.groupby(["class"]).agg({"cty":["mean"],"hwy":["mean"],"cyl":["median"]}).plot()

# %%
cars_df.groupby(["class"]).agg({"cty":["mean"],"hwy":["mean"]})
# Out:
#                   cty        hwy
#                  mean       mean
# class
# 2seater     15.400000  24.800000
# compact     20.127660  28.297872
# midsize     18.800000  27.325000
# minivan     15.818182  22.363636
# pickup      13.000000  16.878788
# subcompact  20.371429  28.142857
# suv         13.500000  18.129032
